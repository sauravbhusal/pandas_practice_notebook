# %%
import pandas as pd
import numpy as np

# %%
my_df = pd.read_csv('fci-breeds.csv')
my_df2 = pd.read_csv('dog_data.csv')
my_df3 = pd.read_csv('dog_data_short.csv')
my_df3
# Out:
#                  Breed        Color  DogName  OwnerZip
# 0             COCKAPOO        BROWN  CHARLEY     15236
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238
# 2        BELG MALINOIS      BRINDLE     EICH     15238
# 3                MIXED  BLACK/BROWN    ARROW     15104
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139

# %%
#add column from list
gender = ["Male", "Female", "Male", "Male", "Female"]
my_df3["Gender"] = gender
my_df3
# Out:
#                  Breed        Color  DogName  OwnerZip  Gender
# 0             COCKAPOO        BROWN  CHARLEY     15236    Male
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238  Female
# 2        BELG MALINOIS      BRINDLE     EICH     15238    Male
# 3                MIXED  BLACK/BROWN    ARROW     15104    Male
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139  Female

# %%
#add default values
my_df3["cute"] = ['yes']*len(my_df3)
my_df3
# Out:
#                  Breed        Color  DogName  OwnerZip  Gender cute
# 0             COCKAPOO        BROWN  CHARLEY     15236    Male  yes
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238  Female  yes
# 2        BELG MALINOIS      BRINDLE     EICH     15238    Male  yes
# 3                MIXED  BLACK/BROWN    ARROW     15104    Male  yes
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139  Female  yes

# %%
#add NaN value
my_df3["show dog"] = [np.nan]*len(my_df3)
my_df3
# Out:
#                  Breed        Color  DogName  OwnerZip  Gender cute  show dog
# 0             COCKAPOO        BROWN  CHARLEY     15236    Male  yes       NaN
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238  Female  yes       NaN
# 2        BELG MALINOIS      BRINDLE     EICH     15238    Male  yes       NaN
# 3                MIXED  BLACK/BROWN    ARROW     15104    Male  yes       NaN
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139  Female  yes       NaN

# %%
#add column with .insert() - Allows position
my_df3.insert(1, "Adopted", [True]*len(my_df3), True)
my_df3
# Out:
#                  Breed  Adopted        Color  DogName  OwnerZip  Gender cute  \
# 0             COCKAPOO     True        BROWN  CHARLEY     15236    Male  yes
# 1         GER SHEPHERD     True  BLACK/BROWN   TACODA     15238  Female  yes
# 2        BELG MALINOIS     True      BRINDLE     EICH     15238    Male  yes
# 3                MIXED     True  BLACK/BROWN    ARROW     15104    Male  yes
# 4  AM PIT BULL TERRIER     True  WHITE/BROWN   OAKLEY     15139  Female  yes
#
#    show dog
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
#add column with .assign() - creates new df
my_df4 = my_df3.assign(Cat = [False]*len(my_df3))
my_df4
# Out:
#                  Breed  Adopted        Color  DogName  OwnerZip  Gender cute  \
# 0             COCKAPOO     True        BROWN  CHARLEY     15236    Male  yes
# 1         GER SHEPHERD     True  BLACK/BROWN   TACODA     15238  Female  yes
# 2        BELG MALINOIS     True      BRINDLE     EICH     15238    Male  yes
# 3                MIXED     True  BLACK/BROWN    ARROW     15104    Male  yes
# 4  AM PIT BULL TERRIER     True  WHITE/BROWN   OAKLEY     15139  Female  yes
#
#    show dog    Cat
# 0       NaN  False
# 1       NaN  False
# 2       NaN  False
# 3       NaN  False
# 4       NaN  False

# %%
my_df3
# Out:
#                  Breed  Adopted        Color  DogName  OwnerZip  Gender cute  \
# 0             COCKAPOO     True        BROWN  CHARLEY     15236    Male  yes
# 1         GER SHEPHERD     True  BLACK/BROWN   TACODA     15238  Female  yes
# 2        BELG MALINOIS     True      BRINDLE     EICH     15238    Male  yes
# 3                MIXED     True  BLACK/BROWN    ARROW     15104    Male  yes
# 4  AM PIT BULL TERRIER     True  WHITE/BROWN   OAKLEY     15139  Female  yes
#
#    show dog
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
#remove column
my_df3.drop("DogName", axis=1, inplace=True)

# %%
my_df3
# Out:
#                  Breed  Adopted        Color  OwnerZip  Gender cute  show dog
# 0             COCKAPOO     True        BROWN     15236    Male  yes       NaN
# 1         GER SHEPHERD     True  BLACK/BROWN     15238  Female  yes       NaN
# 2        BELG MALINOIS     True      BRINDLE     15238    Male  yes       NaN
# 3                MIXED     True  BLACK/BROWN     15104    Male  yes       NaN
# 4  AM PIT BULL TERRIER     True  WHITE/BROWN     15139  Female  yes       NaN

# %%
#remove row
my_df3.drop(2 ,axis=0, inplace=True)

# %%
my_df3
# Out:
#                  Breed  Adopted        Color  OwnerZip  Gender cute  show dog
# 0             COCKAPOO     True        BROWN     15236    Male  yes       NaN
# 1         GER SHEPHERD     True  BLACK/BROWN     15238  Female  yes       NaN
# 3                MIXED     True  BLACK/BROWN     15104    Male  yes       NaN
# 4  AM PIT BULL TERRIER     True  WHITE/BROWN     15139  Female  yes       NaN
