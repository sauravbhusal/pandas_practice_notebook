# %%
import pandas as pd
import numpy as np

# %%
my_df = pd.read_csv('fci-breeds.csv')
my_df
# Out:
#       id                         name                            group  \
# 0      1              ENGLISH POINTER                    Pointing Dogs
# 1      2               ENGLISH SETTER                    Pointing Dogs
# 2      3           KERRY BLUE TERRIER                         Terriers
# 3      4                CAIRN TERRIER                         Terriers
# 4      5       ENGLISH COCKER SPANIEL                       Retrievers
# ..   ...                          ...                              ...
# 351  366               ESTONIAN HOUND  Scent hounds and related breeds
# 352  367  MINIATURE AMERICAN SHEPHERD         Sheepdogs and Cattledogs
# 353  368         TRANSMONTANO MASTIFF           Pinscher and Schnauzer
# 354  369          CONTINENTAL BULLDOG           Pinscher and Schnauzer
# 355  370            VALENCIAN TERRIER                         Terriers
#
#                                     section provisional  \
# 0    British and Irish Pointers and Setters         NaN
# ...

# %%
#counting distinct value in DESCENDING ORDER
my_df['group'].value_counts()
# Out:
# group
# Scent hounds and related breeds    72
# Pinscher and Schnauzer             55
# Spitz and primitive types          48
# Sheepdogs and Cattledogs           47
# Pointing Dogs                      36
# Terriers                           35
# Companion and Toy Dogs             27
# Retrievers                         22
# Sighthounds                        13
# Dachshunds                          1
# Name: count, dtype: int64

# %%
#counting distinct value in ASCENDING ORDER
my_df['group'].value_counts(ascending=True)
# Out:
# group
# Dachshunds                          1
# Sighthounds                        13
# Retrievers                         22
# Companion and Toy Dogs             27
# Terriers                           35
# Pointing Dogs                      36
# Sheepdogs and Cattledogs           47
# Spitz and primitive types          48
# Pinscher and Schnauzer             55
# Scent hounds and related breeds    72
# Name: count, dtype: int64

# %%
#dog names without NAN(Not A Number)
my_df['name'].value_counts()
# Out:
# name
# ENGLISH POINTER             1
# GREAT DANE                  1
# AKITA                       1
# ALPINE DACHSBRACKE          1
# PUG                         1
#                            ..
# ENGLISH SPRINGER SPANIEL    1
# IRISH WATER SPANIEL         1
# FIELD SPANIEL               1
# LABRADOR RETRIEVER          1
# VALENCIAN TERRIER           1
# Name: count, Length: 356, dtype: int64

# %%
#dog names with NAN
my_df['name'].value_counts(dropna=False)
# Out:
# name
# ENGLISH POINTER             1
# GREAT DANE                  1
# AKITA                       1
# ALPINE DACHSBRACKE          1
# PUG                         1
#                            ..
# ENGLISH SPRINGER SPANIEL    1
# IRISH WATER SPANIEL         1
# FIELD SPANIEL               1
# LABRADOR RETRIEVER          1
# VALENCIAN TERRIER           1
# Name: count, Length: 356, dtype: int64

# %%
#get relative frequency - percentage
my_df['name'].value_counts(normalize=True)
# Out:
# name
# ENGLISH POINTER             0.002809
# GREAT DANE                  0.002809
# AKITA                       0.002809
# ALPINE DACHSBRACKE          0.002809
# PUG                         0.002809
#                               ...
# ENGLISH SPRINGER SPANIEL    0.002809
# IRISH WATER SPANIEL         0.002809
# FIELD SPANIEL               0.002809
# LABRADOR RETRIEVER          0.002809
# VALENCIAN TERRIER           0.002809
# Name: proportion, Length: 356, dtype: float64

# %%
#get specific item count
#my_df['name'].value_counts()['PUG']
my_df['group'].value_counts()['Retrievers']
# Out:
# 22

# %%
#count unique values - size
my_df.groupby('name').size()
# Out:
# name
# AFFENPINSCHER                             1
# AFGHAN HOUND                              1
# AIREDALE TERRIER                          1
# AKITA                                     1
# ALASKAN MALAMUTE                          1
#                                          ..
# WIREHAIRED SLOVAKIAN POINTER              1
# XOLOITZCUINTLE                            1
# YAKUTIAN LAIKA                            1
# YORKSHIRE TERRIER                         1
# YUGOSLAVIAN SHEPHERD DOG - SHARPLANINA    1
# Length: 356, dtype: int64

# %%
#count uinque values - count
my_df.groupby('name').count()
# Out:
#                                         id  group  section  provisional  \
# name
# AFFENPINSCHER                            1      1        1            0
# AFGHAN HOUND                             1      1        1            0
# AIREDALE TERRIER                         1      1        1            0
# AKITA                                    1      1        1            0
# ALASKAN MALAMUTE                         1      1        1            0
# ...                                     ..    ...      ...          ...
# WIREHAIRED SLOVAKIAN POINTER             1      1        1            0
# XOLOITZCUINTLE                           1      1        1            0
# YAKUTIAN LAIKA                           1      1        1            1
# YORKSHIRE TERRIER                        1      1        1            0
# YUGOSLAVIAN SHEPHERD DOG - SHARPLANINA   1      1        1            0
#
#                                         country  url  image  pdf
# name
# ...

# %%
#get a count of all columns across all columns
my_df.apply(pd.value_counts)
# Out:
#                                                      id  name  group  section  \
# 1                                                   1.0   NaN    NaN      NaN
# 2                                                   1.0   NaN    NaN      NaN
# 50                                                  1.0   NaN    NaN      NaN
# 51                                                  1.0   NaN    NaN      NaN
# 52                                                  1.0   NaN    NaN      NaN
# ...                                                 ...   ...    ...      ...
# https://www.fci.be/Nomenclature/Standards/125g0...  NaN   NaN    NaN      NaN
# https://www.fci.be/Nomenclature/Standards/124g0...  NaN   NaN    NaN      NaN
# https://www.fci.be/Nomenclature/Standards/123g0...  NaN   NaN    NaN      NaN
# https://www.fci.be/Nomenclature/Standards/122g0...  NaN   NaN    NaN      NaN
# https://www.fci.be/Nomenclature/Standards/370g0...  NaN   NaN    NaN      NaN
#
# ...
