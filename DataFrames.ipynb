# %%
import pandas as pd
import numpy as np
from numpy.random import randn

# %%
my_data = randn(4,3)#random numbers with 4 rows and 3 columns
my_rows = ["A", "B", "C", "D"]
my_cols = ["Monday", "Tuesday", "Friday"]

# %%
#creating data frame
my_df = pd.DataFrame(my_data, my_rows, my_cols)
my_df
# Out:
#      Monday   Tuesday    Friday
# A -0.135480  0.253269  1.045633
# B -0.170277 -0.797706  1.717196
# C  1.485292 -0.823652  0.506905
# D  0.200944 -1.585939  1.035207

# %%
#importing csv file
my_df2 = pd.read_csv('deniro.csv', on_bad_lines='skip')
my_df2
# Out:
#     Year   "Score"                  "Title"
# 0   1968        86              "Greetings"
# 1   1970        17            "Bloody Mama"
# 2   1971        40            "Born to Win"
# 3   1973        98           "Mean Streets"
# 4   1973        88   "Bang the Drum Slowly"
# ..   ...       ...                      ...
# 79  2014         9            "The Bag Man"
# 80  2015        60                    "Joy"
# 81  2015        26                  "Heist"
# 82  2015        61             "The Intern"
# 83  2016        11          "Dirty Grandpa"
#
# [84 rows x 3 columns]

# %%
my_df3 = pd.read_csv('addresses.csv', on_bad_lines='skip')
my_df3
# Out:
#                     John       Doe                 120 jefferson st.  \
# 0                   Jack  McGinnis                      220 hobo Av.
# 1          John "Da Man"    Repici                 120 Jefferson St.
# 2                Stephen     Tyler  7452 Terrace "At the Plaza" road
# 3                    NaN  Blankman                               NaN
# 4  Joan "the bone", Anne       Jet               9th, at Terrace plc
#
#      Riverside   NJ   08075
# 0        Phila   PA    9119
# 1    Riverside   NJ    8075
# 2     SomeTown   SD   91234
# 3     SomeTown   SD     298
# 4  Desert City   CO     123

# %%
#pulling out row
my_df3.loc[3]
# Out:
# John                      NaN
# Doe                  Blankman
# 120 jefferson st.         NaN
# Riverside            SomeTown
#  NJ                        SD
#  08075                    298
# Name: 3, dtype: object

# %%
#pulling out multiple rows
my_df3.loc[[0, 3, 2]]
# Out:
#       John       Doe                 120 jefferson st. Riverside   NJ   08075
# 0     Jack  McGinnis                      220 hobo Av.     Phila   PA    9119
# 3      NaN  Blankman                               NaN  SomeTown   SD     298
# 2  Stephen     Tyler  7452 Terrace "At the Plaza" road  SomeTown   SD   91234

# %%
my_df4 = pd.read_csv('fci-breeds.csv')
my_df4
# Out:
#       id                         name                            group  \
# 0      1              ENGLISH POINTER                    Pointing Dogs
# 1      2               ENGLISH SETTER                    Pointing Dogs
# 2      3           KERRY BLUE TERRIER                         Terriers
# 3      4                CAIRN TERRIER                         Terriers
# 4      5       ENGLISH COCKER SPANIEL                       Retrievers
# ..   ...                          ...                              ...
# 351  366               ESTONIAN HOUND  Scent hounds and related breeds
# 352  367  MINIATURE AMERICAN SHEPHERD         Sheepdogs and Cattledogs
# 353  368         TRANSMONTANO MASTIFF           Pinscher and Schnauzer
# 354  369          CONTINENTAL BULLDOG           Pinscher and Schnauzer
# 355  370            VALENCIAN TERRIER                         Terriers
#
#                                     section provisional  \
# 0    British and Irish Pointers and Setters         NaN
# ...

# %%
#grabbing first 5 rows
my_df4.head()
# Out:
#    id                    name          group  \
# 0   1         ENGLISH POINTER  Pointing Dogs
# 1   2          ENGLISH SETTER  Pointing Dogs
# 2   3      KERRY BLUE TERRIER       Terriers
# 3   4           CAIRN TERRIER       Terriers
# 4   5  ENGLISH COCKER SPANIEL     Retrievers
#
#                                   section provisional        country  \
# 0  British and Irish Pointers and Setters         NaN  GREAT BRITAIN
# 1  British and Irish Pointers and Setters         NaN  GREAT BRITAIN
# 2         Large and medium sized Terriers         NaN        IRELAND
# 3                    Small sized Terriers         NaN  GREAT BRITAIN
# 4                           Flushing Dogs         NaN  GREAT BRITAIN
#
#                                                  url  \
# 0  https://www.fci.be/en/nomenclature/ENGLISH-POI...
# 1  https://www.fci.be/en/nomenclature/ENGLISH-SET...
# 2  https://www.fci.be/en/nomenclature/KERRY-BLUE-...
# 3  https://www.fci.be/en/nomenclature/CAIRN-TERRI...
# ...

# %%
#grabbing certain number of first rows
my_df4.head(10)
# Out:
#    id                    name          group  \
# 0   1         ENGLISH POINTER  Pointing Dogs
# 1   2          ENGLISH SETTER  Pointing Dogs
# 2   3      KERRY BLUE TERRIER       Terriers
# 3   4           CAIRN TERRIER       Terriers
# 4   5  ENGLISH COCKER SPANIEL     Retrievers
# 5   6           GORDON SETTER  Pointing Dogs
# 6   7        AIREDALE TERRIER       Terriers
# 7   8      AUSTRALIAN TERRIER       Terriers
# 8   9      BEDLINGTON TERRIER       Terriers
# 9  10          BORDER TERRIER       Terriers
#
#                                   section provisional        country  \
# 0  British and Irish Pointers and Setters         NaN  GREAT BRITAIN
# 1  British and Irish Pointers and Setters         NaN  GREAT BRITAIN
# 2         Large and medium sized Terriers         NaN        IRELAND
# 3                    Small sized Terriers         NaN  GREAT BRITAIN
# 4                           Flushing Dogs         NaN  GREAT BRITAIN
# ...

# %%
#grabbing last 5 rows
my_df4.tail()
# Out:
#       id                         name                            group  \
# 351  366               ESTONIAN HOUND  Scent hounds and related breeds
# 352  367  MINIATURE AMERICAN SHEPHERD         Sheepdogs and Cattledogs
# 353  368         TRANSMONTANO MASTIFF           Pinscher and Schnauzer
# 354  369          CONTINENTAL BULLDOG           Pinscher and Schnauzer
# 355  370            VALENCIAN TERRIER                         Terriers
#
#                              section provisional                   country  \
# 351                     Scent hounds    9/4/2019                   ESTONIA
# 352                        Sheepdogs    9/4/2019  UNITED STATES OF AMERICA
# 353                   Molossian type   2/26/2020                  PORTUGAL
# 354                   Molossian type   3/30/2022               SWITZERLAND
# 355  Large and medium sized Terriers   6/21/2022                     SPAIN
#
#                                                    url  \
# ...

# %%
#grabbing certain number of last rows
my_df4.tail(7)
# Out:
#       id                         name                            group  \
# 349  364        BOHEMIAN SHEPHERD DOG         Sheepdogs and Cattledogs
# 350  365               YAKUTIAN LAIKA        Spitz and primitive types
# 351  366               ESTONIAN HOUND  Scent hounds and related breeds
# 352  367  MINIATURE AMERICAN SHEPHERD         Sheepdogs and Cattledogs
# 353  368         TRANSMONTANO MASTIFF           Pinscher and Schnauzer
# 354  369          CONTINENTAL BULLDOG           Pinscher and Schnauzer
# 355  370            VALENCIAN TERRIER                         Terriers
#
#                              section provisional                   country  \
# 349                        Sheepdogs   4/29/2019            CZECH REPUBLIC
# 350               Nordic Sledge Dogs    9/4/2019        RUSSIAN FEDERATION
# 351                     Scent hounds    9/4/2019                   ESTONIA
# 352                        Sheepdogs    9/4/2019  UNITED STATES OF AMERICA
# ...

# %%
#get info about the dataframe
my_df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 356 entries, 0 to 355
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           356 non-null    int64
#  1   name         356 non-null    object
#  2   group        356 non-null    object
#  3   section      355 non-null    object
#  4   provisional  12 non-null     object
#  5   country      356 non-null    object
#  6   url          356 non-null    object
#  7   image        245 non-null    object
#  8   pdf          355 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 25.2+ KB

# %%
#get shape of rows and columns
my_df4.shape
# Out:
# (356, 9)
